# %% [markdown]
# dataframes

# %%
import pandas as pd
data={"Name":["Alice","Bob"],"Age" :[25,30]}
j=pd.DataFrame(data)
print(j)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# Pointer Functions

# %%
import pandas as pd
data=[["aryan",23],["Rajesh",35]]
j=pd.DataFrame(data,columns=["Name","Age"])
print(j)
print(j.describe())
# Out:
#      Name  Age
# 0   aryan   23
# 1  Rajesh   35
#              Age
# count   2.000000
# mean   29.000000
# std     8.485281
# min    23.000000
# 25%    26.000000
# 50%    29.000000
# 75%    32.000000
# max    35.000000

# %%
import pandas as pd
data={"Name":["jeff","Kumar"],"Age" :[23,38]}
df=pd.DataFrame(data)
print(df[df["Name"]=="jeff"])
print(df.loc(0))
# Out:
#    Name  Age
# 0  jeff   23
# ...

# %%
import pandas as pd
data={"Name" : ["ranjiv","abanyu"], "Age" : [24,66]}
df=pd.DataFrame(data)
df["Age"]=[28,399]
print(df[df["Age"]>25])
# Out:
#      Name  Age
# 0  ranjiv   28
# 1  abanyu  399
#     Name    Age
# 0  False  False
# 1  False  False

# %% [markdown]
# Merging & Joining

# %%
import pandas as pd
data1={"id" : [0,1],"name" :["Sundar","Kp ganesh"], "age" : [44,78]}
data2={"id" : [1,0], "Gender" : ["M","NB"]}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
pd.merge(df1,df2, on="id")
# Out:
#    id       name  age Gender
# 0   0     Sundar   44     NB
# 1   1  Kp ganesh   78      M

# %%
import pandas as pd
data1={"id" : [0,1],"name" :["Sundar","Kp ganesh"], "age" : [44,78]}
data2={"id" : [1,0], "Gender" : ["M","NB"]}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
df1.to_csv("output.xml",index=False)

# %%
import pandas as pd
z=pd.read_xml("output.xml")
print(z)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[68], line 2
#       1 import pandas as pd
# ----> 2 z=pd.read_xml("output.xml")
#       3 print(z)
#
# File c:\Users\JEFF JOSEPH\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\xml.py:1138, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#     860 r"""
#     861 Read XML document into a :class:`~pandas.DataFrame` object.
#     862
#    (...)   1134 1      1  <NA>  4.5  False  b 2019-12-31
#    1135 """
#    1136 check_dtype_backend(dtype_backend)
# -> 1138 return _parse(
#    1139     path_or_buffer=path_or_buffer,
#    1140     xpath=xpath,
#    1141     namespaces=namespaces,
#    1142     elems_only=elems_only,
#    1143     attrs_only=attrs_only,
# ...
